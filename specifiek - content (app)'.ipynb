# %% [markdown]
# # 1042020_data_variablesonliterature.xlsx 'specifiek - content (app)'

# %%
#imports
import pandas as pd
import datetime as dt
import numpy as np
import itertools
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:/Users/fdnecker/OneDrive - UGent/UGent/2019-2020/Doctoraat Floor/2019-2020/Smartphone_slaap_SimonA/MobileDNA data/input/ppn_logdagengrgl5.xlsx")

# %% [markdown]
# Nu een deel op basis van fancyname: specifieke applicaties en deel op basis van category (game categorieën)

# %% [markdown]
# ## (1) fancyname analyse

# %% [markdown]
# inhoud = Instagram, Facebook, Snapchat, Messenger, Chrome, Whatsapp, Google, Clock, Google Play, Google Drive, Cold Turkey, Forest, Youtube, Yelo, Stievie, Spotify, Google Music, Samsung Music,
# Twitter, Reddit, VRTNWS, Netflix, 9GAG, Google Games

# %% [markdown]
# ### gem_freq_d_...

# %% [markdown]
# ###### = gemiddelde dagelijkse frequentie van smartphonegebruik met specifieke applicatie

# %%
gem_freq_d = df.groupby(['id', 'dag', 'fancyname' ])['gebruik'].count().groupby(['id', 'fancyname']).mean().to_frame()

# %%
gem_freq_d = gem_freq_d.reset_index()

# %%
gem_freq_d
# Out:
#                                         id  \
# 0     025a9d5a-8728-434d-9de6-9c263e7bf5cc
# 1     025a9d5a-8728-434d-9de6-9c263e7bf5cc
# 2     025a9d5a-8728-434d-9de6-9c263e7bf5cc
# 3     025a9d5a-8728-434d-9de6-9c263e7bf5cc
# 4     025a9d5a-8728-434d-9de6-9c263e7bf5cc
# ...                                    ...
# 3052  f9b010d8-45b9-498f-a465-b6355cbdd7e3
# 3053  f9b010d8-45b9-498f-a465-b6355cbdd7e3
# 3054  f9b010d8-45b9-498f-a465-b6355cbdd7e3
# 3055  f9b010d8-45b9-498f-a465-b6355cbdd7e3
# 3056  f9b010d8-45b9-498f-a465-b6355cbdd7e3
#
#                                              fancyname   gebruik
# 0                                     Easy Banking App  1.000000
# 1                                             Facebook  6.466667
# 2                                               Google  3.000000
# 3                         Google Chrome: Fast & Secure  2.923077
# 4                                          Google Docs  1.000000
# ...

# %%
ppn_gem_freq_d = pd.pivot_table(gem_freq_d, values='gebruik', index=['id'],
                    columns=['fancyname'])

# %%
ppn_gem_freq_d_need = ppn_gem_freq_d[['Instagram', 'Facebook', 'Snapchat', 
                                     'Messenger – Text and Video Chat for Free', 'Google Chrome: Fast & Secure', 'WhatsApp Messenger',
                                     'Google', 'Clock', 'Google Play services',
                                     'Google Drive', 'Cold Turkey', 'Forest: Stay focused', 
                                     'YouTube', 'Yelo Play', 'Stievie TV kijken', 
                                     'Spotify: Discover new music, podcasts, and songs', 'Google Play Music', 'Samsung Music', 
                                     'Twitter', 'Reddit', 'VRT NWS', 
                                     'Netflix', '9GAG: Funny gifs, pics, fresh memes & viral videos', 'Google Play Games']]

# %%
ppn_gem_freq_d_need.columns = ['gem_freq_d_Insta','gem_freq_d_Facebook','gem_freq_d_Snapchat',
                               'gem_freq_d_Messenger','gem_freq_d_Chrome','gem_freq_d_Whatsapp', 'gem_freq_d_Google',
                               'gem_freq_d_Clock','gem_freq_d_Gplay','gem_freq_d_GDrive',
                              'gem_freq_d_CTurkey','gem_freq_d_Forest','gem_freq_d_Youtube',
                              'gem_freq_d_Yelo','gem_freq_d_Stievie','gem_freq_d_Spotify',
                              'gem_freq_d_GMusic','gem_freq_d_SMusic', 'gem_freq_d_Twitter',
                              'gem_freq_d_Reddit', 'gem_freq_d_VRTNWS',
                              'gem_freq_d_Netflix','gem_freq_d_9GAG','gem_freq_d_GGames']

# %%
ppn_gem_freq_d_need.to_excel('gem_freq_d_app.xlsx')

# %% [markdown]
# ### gem_duur_min_d...

# %% [markdown]
# ###### = gemiddelde dagelijkse duur van smartphonegebruik (minuten) gelinkt met specifieke app.

# %%
gem_duur_d = df.groupby(['id', 'dag', 'fancyname'])['duur_min'].sum().groupby(['id', 'fancyname']).mean().to_frame().reset_index()

# %%
gem_duur_d.head()
# Out:
#                                      id                     fancyname  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc              Easy Banking App
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc                      Facebook
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc                        Google
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc  Google Chrome: Fast & Secure
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc                   Google Docs
#
#    duur_min
# 0  1.873733
# 1  9.404896
# 2  0.784086
# 3  9.041349
# 4  0.415100

# %%
gem_duur_min_d = pd.pivot_table(gem_duur_d, values='duur_min', index=['id'],
                    columns=['fancyname'])

# %%
gem_duur_min_d.head()
# Out:
# fancyname                                  2048      4411  2048 Ultimate  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc        NaN       NaN            NaN
# 11159c15-a951-4219-850d-c33768509b01  10.724833  1.011083            NaN
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668        NaN       NaN            NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92        NaN       NaN            NaN
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2   0.039100       NaN            NaN
#
# fancyname                             2dehands - Gratis zoekertjes  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc                           NaN
# 11159c15-a951-4219-850d-c33768509b01                           NaN
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668                           NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92                           NaN
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2                      2.011983
#
# fancyname                             4 Plaatjes 1 Woord  7 Minute Workout  \
# id
# ...

# %%
gem_duur_min_d_need = gem_duur_min_d[['Instagram', 'Facebook', 'Snapchat', 
                                     'Messenger – Text and Video Chat for Free', 'Google Chrome: Fast & Secure', 'WhatsApp Messenger',
                                     'Google', 'Clock', 'Google Play services',
                                     'Google Drive', 'Cold Turkey', 'Forest: Stay focused', 
                                     'YouTube', 'Yelo Play', 'Stievie TV kijken', 
                                     'Spotify: Discover new music, podcasts, and songs', 'Google Play Music', 'Samsung Music', 
                                     'Twitter', 'Reddit', 'VRT NWS', 
                                     'Netflix', '9GAG: Funny gifs, pics, fresh memes & viral videos', 'Google Play Games']]

# %%
gem_duur_min_d_need.columns = ['gem_duur_min_d_Insta','gem_duur_min_d_Facebook','gem_duur_min_d_Snapchat',
                               'gem_duur_min_d_Messenger','gem_duur_min_d_Chrome','gem_duur_min_d_Whatsapp', 'gem_duur_min_d_Google',
                               'gem_duur_min_d_Clock','gem_duur_min_d_Gplay','gem_duur_min_d_GDrive',
                              'gem_duur_min_d_CTurkey','gem_duur_min_d_Forest','gem_duur_min_d_Youtube',
                              'gem_duur_min_d_Yelo','gem_duur_min_d_Stievie','gem_duur_min_d_Spotify',
                              'gem_duur_min_d_GMusic','gem_duur_min_d_SMusic', 'gem_duur_min_d_Twitter',
                              'gem_duur_min_d_Reddit', 'gem_duur_min_d_VRTNWS',
                              'gem_duur_min_d_Netflix','gem_duur_min_d_9GAG','gem_duur_min_d_GGames']

# %%
gem_duur_min_d_need.to_excel('gem_duur_min_app.xlsx')

# %% [markdown]
# ## per_d_...

# %% [markdown]
# ###### = gemiddelde percentage dagelijkse appevents gelinkt met specifieke app

# %%
appevents_dag_cat = df.groupby(['id', 'dag', 'fancyname' ])['gebruik'].count().to_frame().reset_index()

# %%
appevents_dag_cat.columns = ['id', 'dag','fancyname', 'appevents']

# %%
appevents_dag_cat.head()
# Out:
#                                      id        dag  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
#
#                       fancyname  appevents
# 0                      Facebook          7
# 1                        Google          4
# 2  Google Chrome: Fast & Secure          5
# 3                  Google Drive          2
# 4                     Instagram         24

# %%
appevents_dag = appevents_dag_cat.groupby(['id', 'dag']).sum().reset_index()

# %%
appevents_dag.columns = ['id', 'dag', 'total appevents']

# %%
appevents_percentage_dag = pd.merge(appevents_dag_cat, appevents_dag, on = ['id', 'dag'])

# %%
appevents_percentage_dag
# Out:
#                                          id        dag  \
# 0      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 1      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 2      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 3      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 4      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# ...                                     ...        ...
# 17683  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-05
# 17684  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 17685  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 17686  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 17687  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
#
#                                               fancyname  appevents  \
# 0                                              Facebook          7
# 1                                                Google          4
# 2                          Google Chrome: Fast & Secure          5
# ...

# %%
appevents_percentage_dag['prop_appE'] = appevents_percentage_dag['appevents']/appevents_percentage_dag['total appevents']

# %%
agg_appE = appevents_percentage_dag.groupby(['id', 'fancyname'])['prop_appE'].mean().to_frame()

# %%
agg_appE = agg_appE.reset_index()

# %%
agg_appE.head()
# Out:
#                                      id                     fancyname  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc              Easy Banking App
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc                      Facebook
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc                        Google
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc  Google Chrome: Fast & Secure
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc                   Google Docs
#
#    prop_appE
# 0   0.006329
# 1   0.097027
# 2   0.054192
# 3   0.049378
# 4   0.011400

# %%
per_d_app = pd.pivot_table(agg_appE, values='prop_appE', index=['id'],
                    columns=['fancyname'])

# %%
per_d_app.head()
# Out:
# fancyname                                 2048      4411  2048 Ultimate  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc       NaN       NaN            NaN
# 11159c15-a951-4219-850d-c33768509b01  0.030303  0.034722            NaN
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668       NaN       NaN            NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92       NaN       NaN            NaN
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2  0.002625       NaN            NaN
#
# fancyname                             2dehands - Gratis zoekertjes  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc                           NaN
# 11159c15-a951-4219-850d-c33768509b01                           NaN
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668                           NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92                           NaN
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2                      0.007886
#
# fancyname                             4 Plaatjes 1 Woord  7 Minute Workout  \
# id
# ...

# %%
per_d_app_need = per_d_app[['Instagram', 'Facebook', 'Snapchat', 
                                     'Messenger – Text and Video Chat for Free', 'Google Chrome: Fast & Secure', 'WhatsApp Messenger',
                                     'Google', 'Clock', 'Google Play services',
                                     'Google Drive', 'Cold Turkey', 'Forest: Stay focused', 
                                     'YouTube', 'Yelo Play', 'Stievie TV kijken', 
                                     'Spotify: Discover new music, podcasts, and songs', 'Google Play Music', 'Samsung Music', 
                                     'Twitter', 'Reddit', 'VRT NWS', 
                                     'Netflix', '9GAG: Funny gifs, pics, fresh memes & viral videos', 'Google Play Games']]

# %%
per_d_app_need.columns = ['per_d_Insta','per_d_Facebook','per_d_Snapchat',
                               'per_d_Messenger','per_d_Chrome','per_d_Whatsapp', 'per_d_Google',
                               'per_d_Clock','per_d_Gplay','per_d_GDrive',
                              'per_d_CTurkey','per_d_Forest','per_d_Youtube',
                              'per_d_Yelo','per_d_Stievie','per_d_Spotify',
                              'per_d_GMusic','per_d_SMusic', 'per_d_Twitter',
                              'per_d_Reddit', 'per_d_VRTNWS',
                              'per_d_Netflix','per_d_9GAG','per_d_GGames']

# %%
per_d_app_need.to_excel('per_d_app.xlsx')

# %% [markdown]
# ## per_d_duur_...

# %% [markdown]
# ###### = gemiddelde percentage van dagelijkse duur smartphonegebruik gelinkt met categorie

# %%
min_id_dag_app = df.groupby(['id', 'dag', 'fancyname'])['duur_min'].sum().to_frame().reset_index()

# %%
min_id_dag_app.head()
# Out:
#                                      id        dag  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
#
#                       fancyname   duur_min
# 0                      Facebook   3.282750
# 1                        Google   0.836117
# 2  Google Chrome: Fast & Secure   2.788083
# 3                  Google Drive   2.736283
# 4                     Instagram  22.652167

# %%
min_id_dag = df.groupby(['id', 'dag'])['duur_min'].sum().to_frame().reset_index()

# %%
min_id_dag.head()
# Out:
#                                      id        dag   duur_min
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21  63.174383
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-22  28.295283
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-23  48.652317
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-24  96.388067
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-25  64.702883

# %%
per_d_duur = pd.merge(min_id_dag_app, min_id_dag, on = ['id', 'dag'])

# %%
per_d_duur.head()
# Out:
#                                      id        dag  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
#
#                       fancyname  duur_min_x  duur_min_y
# 0                      Facebook    3.282750   63.174383
# 1                        Google    0.836117   63.174383
# 2  Google Chrome: Fast & Secure    2.788083   63.174383
# 3                  Google Drive    2.736283   63.174383
# 4                     Instagram   22.652167   63.174383

# %%
per_d_duur.columns = ['id', 'dag', 'fancyname', 'min_app_dag', 'min_dag']

# %%
per_d_duur['per_d_duur'] = per_d_duur['min_app_dag']/per_d_duur['min_dag']

# %%
per_d_duur_app = per_d_duur.groupby(['id', 'fancyname'])['per_d_duur'].mean().to_frame()

# %%
per_d_duur_app = per_d_duur_app.reset_index()

# %%
per_d_duur_app.head()
# Out:
#                                      id                     fancyname  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc              Easy Banking App
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc                      Facebook
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc                        Google
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc  Google Chrome: Fast & Secure
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc                   Google Docs
#
#    per_d_duur
# 0    0.008870
# 1    0.095890
# 2    0.008473
# 3    0.104638
# 4    0.002818

# %%
per_d_duur_apps = pd.pivot_table(per_d_duur_app, values='per_d_duur', index=['id'],
                    columns=['fancyname'])

# %%
per_d_duur_apps_need = per_d_duur_apps[['Instagram', 'Facebook', 'Snapchat', 
                                     'Messenger – Text and Video Chat for Free', 'Google Chrome: Fast & Secure', 'WhatsApp Messenger',
                                     'Google', 'Clock', 'Google Play services',
                                     'Google Drive', 'Cold Turkey', 'Forest: Stay focused', 
                                     'YouTube', 'Yelo Play', 'Stievie TV kijken', 
                                     'Spotify: Discover new music, podcasts, and songs', 'Google Play Music', 'Samsung Music', 
                                     'Twitter', 'Reddit', 'VRT NWS', 
                                     'Netflix', '9GAG: Funny gifs, pics, fresh memes & viral videos', 'Google Play Games']]

# %%
per_d_duur_apps_need.columns = ['per_d_duur_Insta','per_d_duur_Facebook','per_d_duur_Snapchat',
                               'per_d_duur_Messenger','per_d_duur_Chrome','per_d_duur_Whatsapp', 'per_d_duur_Google',
                               'per_d_duur_Clock','per_d_duur_Gplay','per_d_duur_GDrive',
                              'per_d_duur_CTurkey','per_d_duur_Forest','per_d_duur_Youtube',
                              'per_d_duur_Yelo','per_d_duur_Stievie','per_d_duur_Spotify',
                              'per_d_duur_GMusic','per_d_duur_SMusic', 'per_d_duur_Twitter',
                              'per_d_duur_Reddit', 'per_d_duur_VRTNWS',
                              'per_d_duur_Netflix','per_d_duur_9GAG','per_d_duur_GGames']

# %%
per_d_duur_apps_need.to_excel('per_d_duur_apps.xlsx')

# %% [markdown]
# ## (2) category analyse (game categorieën)

# %%
strategy, simulation, arcade, puzzle, action, adventure, role play

# %% [markdown]
# ## gem_freq_d_...

# %% [markdown]
# ###### = gemiddelde dagelijkse frequentie van smartphonegebruik met game categorie

# %%
gem_freq_d = df.groupby(['id', 'dag', 'category' ])['fancyname'].count().groupby(['id', 'category']).mean().to_frame().reset_index()

# %%
ppn_gem_freq_d = pd.pivot_table(gem_freq_d, values='fancyname', index=['id'],
                    columns=['category'])

# %%
ppn_gem_freq_d_need = ppn_gem_freq_d[['strategy','simulation', 'arcade', 'puzzle', 'action', 'adventure', 'role playing']]

# %%
ppn_gem_freq_d_need.columns = ['gem_freq_d_Strategy','gem_freq_d_Simulation','gem_freq_d_Arcade','gem_freq_d_Puzzle','gem_freq_d_Action','gem_freq_d_Adventure','gem_freq_d_Role']

# %%
ppn_gem_freq_d_need.to_excel('gem_freq_d_gamecat.xlsx')

# %% [markdown]
# ## gem_duur_min_d...

# %% [markdown]
# ###### = gemiddelde dagelijkse duur van smartphonegebruik (minuten) gelinkt met game categorie.

# %%
gem_duur_d = df.groupby(['id', 'dag', 'category'])['duur_min'].sum().groupby(['id', 'category']).mean().to_frame().reset_index()

# %%
gem_duur_d.head()
# Out:
#                                      id       category   duur_min
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc  communication  21.817106
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc      education   9.669587
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc  entertainment  76.871567
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc        finance   1.873733
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc        medical   0.137843

# %%
gem_duur_min_d = pd.pivot_table(gem_duur_d, values='duur_min', index=['id'],
                    columns=['category'])

# %%
gem_duur_min_d.head()
# Out:
# category                                action  adventure     arcade  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc       NaN        NaN        NaN
# 11159c15-a951-4219-850d-c33768509b01       NaN   3.842633  50.429467
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668  7.724342        NaN        NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92       NaN        NaN   4.493477
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2       NaN        NaN  49.284944
#
# category                              art & design  auto & vehicles  beauty  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc           NaN              NaN     NaN
# 11159c15-a951-4219-850d-c33768509b01           NaN              NaN     NaN
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668           NaN              NaN     NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92           NaN              NaN     NaN
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2           NaN              NaN     NaN
#
# category                                 board  books & reference  business  \
# id
# ...

# %%
gem_duur_min_d_need = gem_duur_min_d[['strategy','simulation', 'arcade', 'puzzle', 'action', 'adventure', 'role playing']]

# %%
gem_duur_min_d_need.columns = ['gem_duur_min_d_Strategy','gem_duur_min_d_Simulation','gem_duur_min_d_Arcade','gem_duur_min_d_Puzzle','gem_duur_min_d_Action','gem_duur_min_d_Adventure','gem_duur_min_d_Role']

# %%
gem_duur_min_d_need.to_excel('gem_duur_min_gamecat.xlsx')

# %% [markdown]
# ## per_d_...

# %% [markdown]
# ###### = gemiddelde percentage dagelijkse appevents gelinkt met categorie

# %%
appevents_dag_app = df.groupby(['id', 'dag', 'category' ])['fancyname'].count().to_frame().reset_index()

# %%
appevents_dag_app.columns = ['id', 'dag','category', 'appevents']

# %%
appevents_dag_app.head()
# Out:
#                                      id        dag       category  appevents
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21  communication         34
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21        medical          1
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21    photography          0
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21   productivity          2
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21         social         38

# %%
appevents_dag = appevents_dag_app.groupby(['id', 'dag']).sum().reset_index()

# %%
appevents_dag.columns = ['id', 'dag', 'total appevents']

# %%
appevents_percentage_dag = pd.merge(appevents_dag_app, appevents_dag, on = ['id', 'dag'])

# %%
appevents_percentage_dag
# Out:
#                                          id        dag  \
# 0      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 1      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 2      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 3      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# 4      025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21
# ...                                     ...        ...
# 13416  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 13417  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 13418  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 13419  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
# 13420  f9b010d8-45b9-498f-a465-b6355cbdd7e3 2019-01-06
#
#                       category  appevents  total appevents
# 0                communication         34               82
# 1                      medical          1               82
# 2                  photography          0               82
# 3                 productivity          2               82
# ...

# %%
appevents_percentage_dag['prop_appE'] = appevents_percentage_dag['appevents']/appevents_percentage_dag['total appevents']

# %%
agg_appE = appevents_percentage_dag.groupby(['id', 'category'])['prop_appE'].mean().to_frame().reset_index()

# %%
agg_appE.head()
# Out:
#                                      id       category  prop_appE
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc  communication   0.337595
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc      education   0.095921
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc  entertainment   0.119000
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc        finance   0.006329
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc        medical   0.021176

# %%
per_d_gamecat = pd.pivot_table(agg_appE, values='prop_appE', index=['id'],
                    columns=['category'])

# %%
per_d_gamecat.head()
# Out:
# category                                action  adventure    arcade  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc       NaN        NaN       NaN
# 11159c15-a951-4219-850d-c33768509b01       NaN   0.027371  0.108980
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668  0.015424        NaN       NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92       NaN        NaN  0.033798
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2       NaN        NaN  0.050921
#
# category                              art & design  auto & vehicles  beauty  \
# id
# 025a9d5a-8728-434d-9de6-9c263e7bf5cc           NaN              NaN     NaN
# 11159c15-a951-4219-850d-c33768509b01           NaN              NaN     NaN
# 1201c8b4-6a0b-45f0-ac63-04b258d6d668           NaN              NaN     NaN
# 12efa7c1-14af-4a50-ad7d-10d76c77af92           NaN              NaN     NaN
# 130d3a79-9b84-43c3-b279-5ddb3c1390d2           NaN              NaN     NaN
#
# category                                 board  books & reference  business  \
# id
# ...

# %%
per_d_gamecat_need = per_d_gamecat[['strategy','simulation', 'arcade', 'puzzle', 'action', 'adventure', 'role playing']]

# %%
per_d_gamecat_need.columns = ['per_d_Strategy','per_d_Simulation','per_d_Arcade','per_d_Puzzle','per_d_Action','per_d_Adventure','per_d_Role']

# %%
per_d_gamecat_need.to_excel('per_d_gamecat_need.xlsx')

# %% [markdown]
# ## per_d_duur_...

# %% [markdown]
# ###### = gemiddelde percentage van dagelijkse duur smartphonegebruik gelinkt met categorie

# %%
min_id_dag_gamecat = df.groupby(['id', 'dag', 'category'])['duur_min'].sum()

# %%
min_id_dag_gamecat = min_id_dag_gamecat.to_frame().reset_index()

# %%
min_id_dag_gamecat.head()
# Out:
#                                      id        dag       category   duur_min
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21  communication  26.148783
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21        medical   0.149750
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21    photography   0.800600
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21   productivity   2.736283
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21         social  30.159217

# %%
min_id_dag = df.groupby(['id', 'dag'])['duur_min'].sum().to_frame().reset_index()

# %%
min_id_dag.head()
# Out:
#                                      id        dag   duur_min
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21  63.174383
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-22  28.295283
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-23  48.652317
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-24  96.388067
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-25  64.702883

# %%
per_d_duur = pd.merge(min_id_dag_gamecat, min_id_dag, on = ['id', 'dag'])

# %%
per_d_duur.head()
# Out:
#                                      id        dag       category  duur_min_x  \
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21  communication   26.148783
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21        medical    0.149750
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21    photography    0.800600
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21   productivity    2.736283
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21         social   30.159217
#
#    duur_min_y
# 0   63.174383
# 1   63.174383
# 2   63.174383
# 3   63.174383
# 4   63.174383

# %%
per_d_duur.columns = ['id', 'dag', 'category', 'min_gamecat_dag', 'min_dag']

# %%
per_d_duur['per_d_duur'] = per_d_duur['min_gamecat_dag']/per_d_duur['min_dag']

# %%
per_d_duur_cat = per_d_duur.groupby(['id', 'category'])['per_d_duur'].mean().to_frame().reset_index()

# %%
per_d_duur_cat.head()
# Out:
#                                      id       category  per_d_duur
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc  communication    0.219048
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc      education    0.089341
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc  entertainment    0.490225
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc        finance    0.008870
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc        medical    0.001976

# %%
per_d_duur_gamecategories = pd.pivot_table(per_d_duur, values='per_d_duur', index=['id'],
                    columns=['category'])

# %%
per_d_duur_gamecategories_need = per_d_duur_gamecategories[['strategy','simulation', 'arcade', 'puzzle', 'action', 'adventure', 'role playing']]

# %%
per_d_duur_gamecategories_need.columns = ['per_d_duur_Strategy','per_d_duur_Simulation','per_d_duur_Arcade','per_d_duur_Puzzle','per_d_duur_Action','per_d_duur_Adventure','per_d_duur_Role']

# %%
per_d_duur_gamecategories_need.to_excel('per_d_duur_gamecat.xlsx')

# %%
appevents_dag.head()
# Out:
#                                      id        dag  total appevents
# 0  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-21               82
# 1  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-22               26
# 2  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-23               24
# 3  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-24               64
# 4  025a9d5a-8728-434d-9de6-9c263e7bf5cc 2018-12-25               36

# %%
appevents_dag.groupby(['id'])['total appevents'].mean().to_frame().reset_index()
# Out:
#                                        id  total appevents
# 0    025a9d5a-8728-434d-9de6-9c263e7bf5cc        63.411765
# 1    11159c15-a951-4219-850d-c33768509b01        86.882353
# 2    1201c8b4-6a0b-45f0-ac63-04b258d6d668       131.705882
# 3    12efa7c1-14af-4a50-ad7d-10d76c77af92       108.000000
# 4    130d3a79-9b84-43c3-b279-5ddb3c1390d2       211.000000
# ..                                    ...              ...
# 101  f29e3bf2-8b9a-48a5-a83f-dcff88fe9b70       130.705882
# 102  f3214263-3140-4687-bd61-1fbc68623b3f       214.235294
# 103  f3d282d8-1be9-4cde-aa37-21e4dbacd77b        79.882353
# 104  f6b9965f-312a-44e8-a54c-ea16242894fa        38.176471
# 105  f9b010d8-45b9-498f-a465-b6355cbdd7e3        24.352941
#
# [106 rows x 2 columns]
